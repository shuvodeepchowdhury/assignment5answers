# %% [raw]
# 1. What does an empty dictionary's code look like?
#
# ANS:-An empty dictionary code looks like ----> d={}
#
# 2. What is the value of a dictionary value with the key 'foo' and the value 42?
#
# ANS:- here value= 42.
#
# 3. What is the most significant distinction between a dictionary and a list?
#
# ANS:-A dictionary elements are in key and value pair like d{'k1':'abcd','k2':'efg'}.
#
#        whereas a set consist of direct elements without key like s={1,2,3,4,'abcd'}
#
# 4. What happens if you try to access spam['foo'] if spam is {'bar': 100}?
#
# ANS:- spam={'bar': 100}
#        spam['foo']
#
#                         KeyError                                  Traceback (most recent call last)
#                                 Input In [6], in <cell line: 1>()
#                          ----> 1 spam['foo']
#                          KeyError: 'foo'
#
#
# 5. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.keys()?
#
# ANS:- spam ={'cat':'sylvester'}
#       'cat' in spam
#       True
#
#       'cat' in spam.keys()
#        True
#
#
# 6. If a dictionary is stored in spam, what is the difference between the expressions 'cat' in spam and 'cat' in spam.values()?
#
# ANS:-spam ={'cat':'sylvester'}
#     'cat' in spam.values()
#      False
#
# 7. What is a shortcut for the following code?
# if 'color' not in spam:
# spam['color'] = 'black'
#
# ANS:- using setdefault() which Inserts key with a value of default if key is not in the dictionary.
#
#          spam ={'cat':'sylvester'}
#          spam.setdefault('color','black')
#          spam
#          {'cat': 'sylvester', 'color': 'black'}
#
# 8. How do you "pretty print" dictionary values using which module and function?
#
# ANS:-import pprint
#   d = [ {'Name': 'cat', 'Age': '2', 'kingdom': 'animal'},
#       {'Name': 'dog', 'Age': '4', 'kingdom': 'animal'},
#       {'Name': 'Ant', 'Age': '1', 'kingdom': 'insect'},
#       {'Name': 'tiger', 'Age': '6', 'kingdom': 'animal'}]
# ]
#
# pprint.pprint(d)
#       [{'Age': '2', 'kingdom': 'animal', 'Name': 'cat'},
#       {'Age': '4', 'kingdom': 'animal', 'Name': 'dog'},
#       {'Age': '1', 'kingdom': 'insect', 'Name': 'Ant'},
#       {'Age': '6', 'kingdom': 'animal', 'Name': 'tiger'}]
#
# print(d)
#
# [ {'Name': 'cat', 'Age': '2', 'kingdom': 'animal'},{'Name': 'dog', 'Age': '4', 'kingdom': 'animal'},{'Name': 'Ant', 'Age': '1',    'kingdom': 'insect'},{'Name': 'tiger', 'Age': '6', 'kingdom': 'animal'}]
